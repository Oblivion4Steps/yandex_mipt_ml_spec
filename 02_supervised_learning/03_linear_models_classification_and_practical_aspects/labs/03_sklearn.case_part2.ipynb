# %% [markdown]
# # Sklearn

# %% [markdown]
# ## Bike Sharing Demand
# Задача на kaggle: https://www.kaggle.com/c/bike-sharing-demand
#
# По историческим данным о прокате велосипедов и погодных условиях необходимо спрогнозировтаь спрос на прокат велосипедов.
#
# В исходной постановке задачи доступно 11 признаков: https://www.kaggle.com/c/prudential-life-insurance-assessment/data
#
# В наборе признаков присутсвуют вещественные, категориальные, и бинарные данные.
#
# Для демонстрации используется обучающая выборка из исходных данных train.csv, файлы для работы прилагаются.

# %% [markdown]
# ### Библиотеки

# %%
from sklearn import model_selection, linear_model, metrics, pipeline, preprocessing
import pandas as pd

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Загрузка данных

# %%
raw_data = pd.read_csv('bike_sharing_demand.csv', header=0, sep =',')

# %%
raw_data.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Обучение и отложенный тест

# %%
raw_data.datetime = raw_data.datetime.apply(pd.to_datetime)

# %%
raw_data.datetime[:5]
# Out:
# 0   2011-01-01 00:00:00
# 1   2011-01-01 01:00:00
# 2   2011-01-01 02:00:00
# 3   2011-01-01 03:00:00
# 4   2011-01-01 04:00:00
# Name: datetime, dtype: datetime64[ns]

# %%
raw_data['month'] = raw_data.datetime.apply(lambda x: x.month)
raw_data['hour'] = raw_data.datetime.apply(lambda x: x.hour)

# %%
hold_out_train_data = raw_data.iloc[:-1000, :]
hold_out_test_data = raw_data.iloc[-1000:, :]

# %%
print(raw_data.shape, hold_out_train_data.shape, hold_out_test_data.shape)
# Out:
# (10886, 14) (9886, 14) (1000, 14)

# %%
#обучение
train_labels = hold_out_train_data['count'].values
train_data = hold_out_train_data.drop(['datetime', 'count', 'casual', 'registered'], axis=1)

# %%
#тест
test_labels = hold_out_test_data['count'].values
test_data = hold_out_test_data.drop(['datetime', 'count', 'casual', 'registered'], axis=1)

# %%
train_data[:5]
# Out:
#    season  holiday  workingday  weather  temp   atemp  humidity  windspeed  \
# 0       1        0           0        1  9.84  14.395        81        0.0
# 1       1        0           0        1  9.02  13.635        80        0.0
# 2       1        0           0        1  9.02  13.635        80        0.0
# 3       1        0           0        1  9.84  14.395        75        0.0
# 4       1        0           0        1  9.84  14.395        75        0.0
#
#    month  hour
# 0      1     0
# 1      1     1
# 2      1     2
# 3      1     3
# 4      1     4

# %%
binary_data_columns = ['holiday', 'workingday']
binary_data_indices = np.array([(column in binary_data_columns) 
                                for column in train_data.columns])

# %%
print(binary_data_columns)
print(binary_data_indices)
# Out:
# ['holiday', 'workingday']
# [False  True  True False False False False False False False]

# %%
categorical_data_columns = ['season', 'weather', 'month'] 
categorical_data_indices = np.array([(column in categorical_data_columns) 
                                     for column in train_data.columns])

# %%
print(categorical_data_columns)
print(categorical_data_indices)
# Out:
# ['season', 'weather', 'month']
# [ True False False  True False False False False  True False]

# %%
numeric_data_columns = ['temp', 'atemp', 'humidity', 'windspeed', 'hour']
numeric_data_indices = np.array([(column in numeric_data_columns) 
                                 for column in train_data.columns])

# %%
print(numeric_data_columns)
print(numeric_data_indices)
# Out:
# ['temp', 'atemp', 'humidity', 'windspeed', 'hour']
# [False False False False  True  True  True  True False  True]

# %% [markdown]
# ### Pipeline

# %%
regressor = linear_model.SGDRegressor(random_state=0, n_iter=3, loss='squared_loss', 
                                      penalty ='l2')

# %%
estimator = pipeline.Pipeline(steps = [  
    ('feature_processing', pipeline.FeatureUnion(transformer_list = [        
            #binary
            ('binary_variables_processing', 
             preprocessing.FunctionTransformer(lambda data: data[:, binary_data_indices])), 
                    
            #numeric
            ('numeric_variables_processing', pipeline.Pipeline(steps = [
                ('selecting', preprocessing.FunctionTransformer(lambda data: data[:, numeric_data_indices])),
                ('scaling', preprocessing.StandardScaler(with_mean = 0))            
                        ])),
        
            #categorical
            ('categorical_variables_processing', pipeline.Pipeline(steps = [
                ('selecting', preprocessing.FunctionTransformer(lambda data: data[:, categorical_data_indices])),
                ('hot_encoding', preprocessing.OneHotEncoder(handle_unknown = 'ignore'))            
                        ])),
        ])),
    ('model_fitting', regressor)
    ]
)

# %%
estimator.fit(train_data, train_labels)
# Out:
# Pipeline(steps=[('feature_processing', FeatureUnion(n_jobs=1,
#        transformer_list=[('binary_variables_processing', FunctionTransformer(accept_sparse=False,
#           func=<function <lambda> at 0x117036c80>, inv_kw_args=None,
#           inverse_func=None, kw_args=None, pass_y=False, validate=True)), ('nume...r=3, penalty='l2', power_t=0.25,
#        random_state=0, shuffle=True, verbose=0, warm_start=False))])

# %%
metrics.mean_absolute_error(test_labels, estimator.predict(test_data))
# Out:
# 120.17177172806856

# %% [markdown]
# ### Подбор параметров

# %%
estimator.get_params().keys()
# Out:
# dict_keys(['model_fitting__learning_rate', 'model_fitting__shuffle', 'feature_processing__numeric_variables_processing__selecting', 'feature_processing__binary_variables_processing__accept_sparse', 'feature_processing__categorical_variables_processing', 'feature_processing__categorical_variables_processing__steps', 'model_fitting__n_iter', 'feature_processing__categorical_variables_processing__hot_encoding', 'model_fitting__random_state', 'feature_processing__numeric_variables_processing__steps', 'feature_processing__categorical_variables_processing__hot_encoding__handle_unknown', 'feature_processing__numeric_variables_processing__scaling__with_std', 'feature_processing__numeric_variables_processing__scaling__copy', 'feature_processing__binary_variables_processing__inverse_func', 'feature_processing__categorical_variables_processing__hot_encoding__n_values', 'feature_processing__transformer_list', 'model_fitting__warm_start', 'feature_processing__categorical_variables_processing__sel
# ...

# %%
parameters_grid = {
    'model_fitting__alpha' : [0.0001, 0.001, 0,1],
    'model_fitting__eta0' : [0.001, 0.05],
}

# %%
grid_cv = model_selection.GridSearchCV(estimator, parameters_grid, 
                                       scoring = 'neg_mean_absolute_error', 
                                       cv=4)

# %%
# %%time
grid_cv.fit(train_data, train_labels)
# Out:
# CPU times: user 2.12 s, sys: 145 ms, total: 2.26 s
# Wall time: 2.36 s
# GridSearchCV(cv=4, error_score='raise',
#        estimator=Pipeline(steps=[('feature_processing', FeatureUnion(n_jobs=1,
#        transformer_list=[('binary_variables_processing', FunctionTransformer(accept_sparse=False,
#           func=<function <lambda> at 0x117036c80>, inv_kw_args=None,
#           inverse_func=None, kw_args=None, pass_y=False, validate=True)), ('nume...r=3, penalty='l2', power_t=0.25,
#        random_state=0, shuffle=True, verbose=0, warm_start=False))]),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'model_fitting__eta0': [0.001, 0.05], 'model_fitting__alpha': [0.0001, 0.001, 0, 1]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='neg_mean_absolute_error', verbose=0)

# %%
print(grid_cv.best_score_)
print(grid_cv.best_params_)
# Out:
# -106.601939797
# {'model_fitting__eta0': 0.05, 'model_fitting__alpha': 0.001}

# %% [markdown]
# ### Оценка по отложенному тесту

# %%
test_predictions = grid_cv.best_estimator_.predict(test_data)

# %%
metrics.mean_absolute_error(test_labels, test_predictions)
# Out:
# 125.11055616822884

# %%
print(test_labels[:20])
# Out:
# [525 835 355 222 228 325 328 308 346 446 943 838 531 432 195 181 199  49
#   17  16]

# %%
print(test_predictions[:20])
# Out:
# [ 153.28859124  181.89867268  227.64068051  262.47727954  278.91095558
#   279.82091706  301.6223314   333.35079391  336.28447325  348.55425173
#   346.29477487  336.77206344  318.29674096  298.65247956  285.35831745
#   246.0338046   252.72004984   58.96734361   66.43816405   73.90898448]

# %%
pylab.figure(figsize=(6, 4))
pylab.grid(True)
pylab.xlim(-100,1100)
pylab.ylim(-100,1100)
pylab.scatter(train_labels, grid_cv.best_estimator_.predict(train_data), alpha=0.5, color = 'red')
pylab.scatter(test_labels, grid_cv.best_estimator_.predict(test_data), alpha=0.5, color = 'blue')

# %% [markdown]
# ### Другая модель

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor = RandomForestRegressor(random_state=0, max_depth=20, n_estimators=50)

# %%
estimator = pipeline.Pipeline(steps = [       
    ('feature_processing', pipeline.FeatureUnion(transformer_list = [        
            #binary
            ('binary_variables_processing', preprocessing.FunctionTransformer(lambda data: data[:, binary_data_indices])), 
                    
            #numeric
            ('numeric_variables_processing', pipeline.Pipeline(steps = [
                ('selecting', preprocessing.FunctionTransformer(lambda data: data[:, numeric_data_indices])),
                ('scaling', preprocessing.StandardScaler(with_mean = 0, with_std = 1))            
                        ])),
        
            #categorical
            ('categorical_variables_processing', pipeline.Pipeline(steps = [
                ('selecting', preprocessing.FunctionTransformer(lambda data: data[:, categorical_data_indices])),
                ('hot_encoding', preprocessing.OneHotEncoder(handle_unknown = 'ignore'))            
                        ])),
        ])),
    ('model_fitting', regressor)
    ]
)

# %%
estimator.fit(train_data, train_labels)
# Out:
# Pipeline(steps=[('feature_processing', FeatureUnion(n_jobs=1,
#        transformer_list=[('binary_variables_processing', FunctionTransformer(accept_sparse=False,
#           func=<function <lambda> at 0x117f2d2f0>, inv_kw_args=None,
#           inverse_func=None, kw_args=None, pass_y=False, validate=True)), ('nume..._estimators=50, n_jobs=1, oob_score=False, random_state=0,
#            verbose=0, warm_start=False))])

# %%
metrics.mean_absolute_error(test_labels, estimator.predict(test_data))
# Out:
# 79.465803762612722

# %%
test_labels[:10]
# Out:
# array([525, 835, 355, 222, 228, 325, 328, 308, 346, 446])

# %%
estimator.predict(test_data)[:10]
# Out:
# array([ 409.565     ,  505.56      ,  256.14066667,  165.5502619 ,
#         206.48474784,  265.73960439,  254.49615818,  317.85774486,
#         282.66963263,  441.59333333])

# %%
pylab.figure(figsize=(16, 6))

pylab.subplot(1,2,1)
pylab.grid(True)
pylab.xlim(-100,1100)
pylab.ylim(-100,1100)
pylab.scatter(train_labels, grid_cv.best_estimator_.predict(train_data), alpha=0.5, color = 'red')
pylab.scatter(test_labels, grid_cv.best_estimator_.predict(test_data), alpha=0.5, color = 'blue')
pylab.title('linear model')

pylab.subplot(1,2,2)
pylab.grid(True)
pylab.xlim(-100,1100)
pylab.ylim(-100,1100)
pylab.scatter(train_labels, estimator.predict(train_data), alpha=0.5, color = 'red')
pylab.scatter(test_labels, estimator.predict(test_data), alpha=0.5, color = 'blue')
pylab.title('random forest model')
